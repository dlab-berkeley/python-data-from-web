# %% [markdown]
# # Webscraping with Beautiful Soup
# *****
#
#
# ## Intro
#
# In this tutorial, we'll be scraping information on the state senators of Illinois, available [here](http://www.ilga.gov/senate), as well as the list of bills each senator has sponsored (e.g., [here](http://www.ilga.gov/senate/SenatorBills.asp?MemberID=1911&GA=98&Primary=True).

# %% [markdown]
# ## The Tools
#
# 1. [Requests](http://docs.python-requests.org/en/latest/user/quickstart/)
# 2. [Beautiful Soup](http://www.crummy.com/software/BeautifulSoup/bs4/doc/)

# %%
# import required modules
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import time
import re
import sys

# %% [markdown]
# # Part 1: Using Beautiful Soup
# *****

# %% [markdown]
# ## 1.1 Make a Get Request and Read in HTML
#
# We use `requests` library to:
# 1. make a GET request to the page
# 2. read in the html of the page

# %%
# make a GET request
req = requests.get('http://www.ilga.gov/senate/default.asp')
# read the content of the server’s response
src = req.text

# %% [markdown]
# ## 1.2 Soup it
#
# Now we use the `BeautifulSoup` function to parse the reponse into an HTML tree. This returns an object (called a **soup object**) which contains all of the HTML in the original document.

# %%
# parse the response into an HTML tree
soup = BeautifulSoup(src, 'lxml')
# take a look
print(soup.prettify()[:1000])
# Out:
# <html lang="en">
#  <head>
#   <title>
#    Illinois General Assembly - Senate Members
#   </title>
#   <link href="/style/lis.css" rel="stylesheet" type="text/css"/>
#   <link href="/style/print.css" media="print" rel="stylesheet" type="text/css"/>
#   <link href="http://info.er.usgs.gov/public/gils/gilsexec.html" rel="GILS"/>
#   <link href="/LISlogo1.ico" rel="Shortcut Icon"/>
#   <script language="JavaScript" type="text/javascript">
#    <!--
#
# if(window.event + "" == "undefined") event = null;
# function HM_f_PopUp(){return false};
# function HM_f_PopDown(){return false};
# popUp = HM_f_PopUp;
# popDown = HM_f_PopDown;
#
# //-->
#   </script>
#   <!--
#     option explicit
#   -->
#   <meta content='(PICS-1.1 "http://www.weburbia.com/safe/ratings.htm" l r (s 0))' http-equiv="PICS-Label"/>
#   <meta content="Government" name="classification"/>
#   <meta content="Global" name="distribution"/>
#   <meta content="General" name="rating"/>
#   <meta content="IL" name="contactState"/>
#   <meta content="Illinois General Assembly" name="

# %% [markdown]
# ## 1.3 Find Elements
#
# BeautifulSoup has a number of functions to find things on a page. Like other webscraping tools, Beautiful Soup lets you find elements by their:
#
# 1. HTML tags
# 2. HTML Attributes
# 3. CSS Selectors
#
#
# Let's search first for **HTML tags**.
#
# The function `find_all` searches the `soup` tree to find all the elements with an a particular HTML tag, and returns all of those elements.
#
# What does the example below do?

# %%
# find all elements in a certain tag
# these two lines of code are equivilant

# soup.find_all("a")

# %% [markdown]
# **NB**: Because `find_all()` is the most popular method in the Beautiful Soup search API, you can use a shortcut for it. If you treat the BeautifulSoup object as though it were a function, then it’s the same as calling `find_all()` on that object.
#
# These two lines of code are equivalent:

# %%
# soup.find_all("a")
# soup("a")

# %% [markdown]
# That's a lot! Many elements on a page will have the same html tag. For instance, if you search for everything with the `a` tag, you're likely to get a lot of stuff, much of which you don't want. What if we wanted to search for HTML tags ONLY with certain attributes, like particular CSS classes?
#
# We can do this by adding an additional argument to the `find_all`
#
# In the example below, we are finding all the `a` tags, and then filtering those with `class = "sidemenu"`.

# %%
# Get only the 'a' tags in 'sidemenu' class
soup("a", class_="sidemenu")
# Out:
# [<a class="sidemenu" href="/senate/default.asp">  Members  </a>,
#  <a class="sidemenu" href="/senate/committees/default.asp">  Committees  </a>,
#  <a class="sidemenu" href="/senate/schedules/default.asp">  Schedules  </a>,
#  <a class="sidemenu" href="/senate/journals/default.asp">  Journals  </a>,
#  <a class="sidemenu" href="/senate/transcripts/default.asp">  Transcripts  </a>,
#  <a class="sidemenu" href="/senate/rules.asp">  Rules  </a>,
#  <a class="sidemenu" href="/senateaudvid.asp">  Live Audio/Video  </a>]

# %% [markdown]
# Oftentimes a more efficient way to search and find things on a website is by **CSS selector.** For this we have to use a different method, `select()`. Just pass a string into the `.select()` to get all elements with that string as a valid CSS selector.
#
# In the example above, we can use "a.sidemenu" as a CSS selector, which returns all `a` tags with class `sidemenu`.

# %%
# get elements with "a.sidemenu" CSS Selector.
soup.select("a.sidemenu")
# Out:
# [<a class="sidemenu" href="/senate/default.asp">  Members  </a>,
#  <a class="sidemenu" href="/senate/committees/default.asp">  Committees  </a>,
#  <a class="sidemenu" href="/senate/schedules/default.asp">  Schedules  </a>,
#  <a class="sidemenu" href="/senate/journals/default.asp">  Journals  </a>,
#  <a class="sidemenu" href="/senate/transcripts/default.asp">  Transcripts  </a>,
#  <a class="sidemenu" href="/senate/rules.asp">  Rules  </a>,
#  <a class="sidemenu" href="/senateaudvid.asp">  Live Audio/Video  </a>]

# %% [markdown]
# ## Challenge 1
#
# Find all the `<a>` elements in class `mainmenu`

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 1.4 Get Attributes and Text of Elements
#
# Once we identify elements, we want the access information in that element. Oftentimes this means two things:
#
# 1. Text
# 2. Attributes
#
# Getting the text inside an element is easy. All we have to do is use the `text` member of a `tag` object:

# %%
# this is a list
soup.select("a.sidemenu")

# we first want to get an individual tag object
first_link = soup.select("a.sidemenu")[0]

# check out its class
type(first_link)
# Out:
# bs4.element.Tag

# %% [markdown]
# It's a tag! Which means it has a `text` member:

# %%
print(first_link.text)
# Out:
#   Members

# %% [markdown]
# Sometimes we want the value of certain attributes. This is particularly relevant for `a` tags, or links, where the `href` attribute tells us where the link goes.
#
# You can access a tag’s attributes by treating the tag like a dictionary:

# %%
print(first_link['href'])
# Out:
# /senate/default.asp

# %% [markdown]
# ## Challenge 2
#
# Find all the `href` attributes (url) from the mainmenu.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Part 2
# ****
#
# Believe it or not, that's all you need to scrape a website. Let's apply these skills to scrape http://www.ilga.gov/senate/default.asp?GA=98
#
# **NB: we're just going to scrape the 98th general assembly.**
#
# Our goal is to scrape information on each senator, including their:
#     - name
#     - district
#     - party
#
# ## 2.1 First, make the get request and soup it.

# %%
# make a GET request
req = requests.get('http://www.ilga.gov/senate/default.asp?GA=98')
# read the content of the server’s response
src = req.text
# soup it
soup = BeautifulSoup(src, "lxml")

# %%
soup
# Out:
# <html lang="en">
# <head><title>Illinois General Assembly - Senate Members</title>
# <link href="/style/lis.css" rel="stylesheet" type="text/css"/>
# <link href="/style/print.css" media="print" rel="stylesheet" type="text/css"/>
# <link href="http://info.er.usgs.gov/public/gils/gilsexec.html" rel="GILS"/>
# <link href="/LISlogo1.ico" rel="Shortcut Icon"/>
# <script language="JavaScript" type="text/javascript">
# <!--
#
# if(window.event + "" == "undefined") event = null;
# function HM_f_PopUp(){return false};
# function HM_f_PopDown(){return false};
# popUp = HM_f_PopUp;
# popDown = HM_f_PopDown;
#
# //-->
# </script>
# <!--
#     option explicit
#   -->
# <meta content='(PICS-1.1 "http://www.weburbia.com/safe/ratings.htm" l r (s 0))' http-equiv="PICS-Label"/>
# <meta content="Government" name="classification"/>
# <meta content="Global" name="distribution"/>
# <meta content="General" name="rating"/>
# <meta content="IL" name="contactState"/>
# <meta content="Illinois General Assembly" name="siteTitle"/>
# <meta content="Illinois General Assembly, Senate, Members" name="keywords"/>
# <meta content="" name="description"/>
# <meta content="5/29/2002" name="createDate"/>
# <meta content="5/29/2002" name="dateofLastModification"/>
# <meta content="2001-2002" name="timePeriodTextual"/>
# <meta content="0000001" name="originalControlIdentifier"/>
# <meta content="Web Site" name="medium"/>
# <meta content="yes" name="PermanentPublicAccess"/>
# <meta content="Illinois General Assembly" name="agencyProgram"/>
# <meta content="" name="linkage"/>
# <meta content="EN" name="language"/>
# <meta content="State" name="govType"/>
# <meta content="Legislative Information System" name="contactName"/>
# <meta content="LIS Staff Services" name="contactOrganization"/>
# <meta content="705 Stratton Office Building" name="contactStreetAddress1"/>
# <meta content="" name="contactStreetAddress2"/>
# <meta content="Springfield" name="contactCity"/>
# <meta content="62706" name="contactZipcode"/>
# <meta content="webmaster@ilga.gov" name="contactNetworkAddress"/>
# <meta content="217-782-3944" name="contactPhoneNumber"/>
# <meta content="217-524-6059" name="contactFaxNumber"/>
# <meta content="State Of Illinois" name="originatorJurisdiction"/>
# <meta content="Illinois General Assembly" name="originatorOffice"/>
# <meta content="Legislative Information System" name="originatorDepartment"/>
# <meta content="Web Staff" name="originatorDivision"/>
# <meta content="" name="originatorSection"/>
# <meta content="Government--State Government--Illinois General Assembly" name="Classification"/>
# <!-- Begin Body Start -->
# </head><body alink="#9933FF" bgcolor="#FFFFFF" leftmargin="0" link="#3366FF" text="#000000" topmargin="0" vlink="#663366">
# <script language="JavaScript1.2" src="/include/script/HM_Loader.js" type="text/javascript"></script>
# <table align="left" border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr id="PreviousGA">
# <td colspan="4"><a href="/default.asp"><img alt="Illinois General Assembly" border="0" height="49" src="/images/logo_sm.gif" width="462"/></a>
# </td>
# </tr>
# <tr>
# <td align="left" colspan="4" valign="top">
# <table border="0" cellspacing="0" class="mainmenu" width="100%">
# <tr id="PreviousGA">
# <td height="25" nowrap="">  <a class="mainmenu" href="/">Home</a>  </td>
# <td height="25" nowrap="">  <a class="mainmenu" href="/legislation/" onblur="HM_f_PopDown('elMenu1')" onfocus="HM_f_PopUp('elMenu1',event)" onmouseout="HM_f_PopDown('elMenu1')" onmouseover="HM_f_PopUp('elMenu1',event)">Legislation &amp; Laws</a>  </td>
# <td height="25" nowrap="">  <a class="mainmenu" href="/senate/" onblur="HM_f_PopDown('elMenu3')" onfocus="HM_f_PopUp('elMenu3',event)" onmouseout="HM_f_PopDown('elMenu3')" onmouseover="HM_f_PopUp('elMenu3',event)">Senate</a>  </td>
# <td height="25" nowrap="">  <a class="mainmenu" href="/house/" onblur="HM_f_PopDown('elMenu2')" onfocus="HM_f_PopUp('elMenu2',event)" onmouseout="HM_f_PopDown('elMenu2')" onmouseover="HM_f_PopUp('elMenu2',event)">House</a>  </td>
# <td height="25" nowrap="">  <a class="mainmenu" href="/mylegislation/" onblur="HM_f_PopDown('elMenu4')" onfocus="HM_f_PopUp('elMenu4',event)" onmouseout="HM_f_PopDown('elMenu4')" onmouseover="HM_f_PopUp('elMenu4',event)">My Legislation</a>  </td>
# <td height="25" nowrap="">  <a class="mainmenu" href="/sitemap.asp">Site Map</a>  </td>
# <td align="right" height="25" width="99%">
#
#             </td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td valign="top"><br/>
# <table border="0" cellpadding="0" cellspacing="2" class="sidemenu" id="PreviousGA" width="140"><tr><td><a href="/previousga.asp">Previous General Assemblies</a></td></tr></table></td><td class="verticalline" width="1"><img height="1" src="/images/1ptrans.gif" width="1"/></td><td align="left" valign="top" width="99%"><table align="left" border="0" width="490"><tr><td width="100%"><br/>
# <!-- End Body Start -->
# <!--Begin Custom Page Content -->
# <form action="default.asp" method="get" name="member">
# <input name="sortby" type="hidden" value=""/>
# <input name="sortbyformer" type="hidden" value=""/>
# <input name="sortbyGA" type="hidden" value=""/>
# <table border="0" cellpadding="3" cellspacing="1" width="100%">
# <tr><td colspan="5">
# <span class="heading">Illinois State Senators</span>
# <span class="italics">  98th  General Assembly</span><br/>
# <!-- 3/2/09 temp comment out until fixed for GA specific-->
# <!-- add 97th ga currently no info -->
# <a href="98GA_Senate_Leadership.pdf">Leadership</a> <a href="98th_Senate_Officers.pdf">Officers</a> <a href="98GA_Senate_Seating_Chart.pdf">Senate Seating Chart</a>  <span class="content"><b>Democrats:</b> 40   <b>Republicans:</b> 19</span><br/>
# </td></tr>
# <tr>
# <td class="header" width="45%"><a class="filetab" href="javascript:Sort('LastName','',98);" title="Sort by Senator">Senator</a></td>
# <td align="center" class="header" width="15%">Bills</td>
# <td align="center" class="header" width="10%">Committees</td>
# <td align="center" class="header" width="15%"><a class="filetab" href="javascript:Sort('DistrictNumber','',98);" title="Sort by District">District</a></td>
# <td align="center" class="header" width="15%"><a class="filetab" href="javascript:Sort('Party','',98);" title="Sort by Party">Party</a></td>
# </tr>
# <tr><td bgcolor="white" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=1911">Pamela J. Althoff</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=1911">Bills</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=1911">Committees</a></td><td align="center" bgcolor="white" class="detail" width="15%">32</td><td align="center" bgcolor="white" class="detail" width="15%">R</td></tr><tr><td bgcolor="EBEBEB" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=2018">Jason A. Barickman</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=2018">Bills</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=2018">Committees</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%">53</td><td align="center" bgcolor="EBEBEB" class="detail" width="15%">R</td></tr><tr><td bgcolor="white" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=2272">Scott M Bennett</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=2272">Bills</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=2272">Committees</a></td><td align="center" bgcolor="white" class="detail" width="15%">52</td><td align="center" bgcolor="white" class="detail" width="15%">D</td></tr><tr><td bgcolor="EBEBEB" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=2022">Jennifer Bertino-Tarrant</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=2022">Bills</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=2022">Committees</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%">49</td><td align="center" bgcolor="EBEBEB" class="detail" width="15%">D</td></tr><tr><td bgcolor="white" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=2020">Daniel Biss</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=2020">Bills</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=2020">Committees</a></td><td align="center" bgcolor="white" class="detail" width="15%">9</td><td align="center" bgcolor="white" class="detail" width="15%">D</td></tr><tr><td bgcolor="EBEBEB" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=1948">Tim Bivins</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=1948">Bills</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=1948">Committees</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%">45</td><td align="center" bgcolor="EBEBEB" class="detail" width="15%">R</td></tr><tr><td bgcolor="white" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=1880">William E. Brady</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=1880">Bills</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=1880">Committees</a></td><td align="center" bgcolor="white" class="detail" width="15%">44</td><td align="center" bgcolor="white" class="detail" width="15%">R</td></tr><tr><td bgcolor="EBEBEB" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=2023">Melinda Bush</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=2023">Bills</a></td><td alig ...
# </table>
# </form>
# <!--End Custom Page Content-->
# <!--Begin Page End-->
# </td></tr>
# <tr id="PreviousGA">
# <td>
# <table align="center" border="0" cellpadding="0" cellspacing="0" class="footer" width="100%">
# <tr>
# <td align="center" colspan="2"><hr color="navy" noshade="True"/>
# <a class="footer" href="/" title="View the General Assembly web site home page">Home</a> |
#       <a class="footer" href="/legislation/" title="View Legislation and Laws">Legislation &amp; Laws</a> |
#       <a class="footer" href="/house/default.asp" title="View information regarding House of Representatives">House</a> |
#       <a class="footer" href="/senate/default.asp" title="View information regarding Senate">Senate</a> |
#       <a class="footer" href="/mylegislation/default.asp" title="Set up customized queries, create reports for tracking, etc.">My Legislation</a> |
#       <a class="footer" href="/disclaimer.asp" title="Disclaimers regarding the Illinois General Assembly web site">Disclaimers</a> |
#       <a class="footer" href="/contact.asp" title="Contact the Illinois General Assembly Web Support Staff">Email</a>
# </td>
# </tr>
# <tr>
# <td align="center" colspan="2"><hr color="navy" noshade="True"/><br/></td>
# </tr>
# <tr>
# <td align="left" class="footer" width="107">  <img alt="Legislative Information System logo" height="45" src="/images/lislogo.jpg" width="100"/></td>
# <td align="left" class="footer" valign="top">This site is maintained for the Illinois General Assembly
# by the<br/>Legislative Information System, 705 Stratton Building, Springfield, Illinois 62706<br/>
# 217-782-3944   217-782-2050 (TTY)
# <br/>
# </td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# <p> </p><br/>
# </td>
# </tr>
# </table>
# </body>
# </html>
# <!--End Page End-->

# %% [markdown]
# ## 2.2 Find the right elements and text.
#
# Now let's try to get a list of rows in that table. Remember that rows are identified by the `tr` tag.

# %%
# get all tr elements
rows = soup.find_all("tr")
len(rows)
# Out:
# 73

# %%
rows
# Out:
# [<tr id="PreviousGA">
#  <td colspan="4"><a href="/default.asp"><img alt="Illinois General Assembly" border="0" height="49" src="/images/logo_sm.gif" width="462"/></a>
#  </td>
#  </tr>, <tr>
#  <td align="left" colspan="4" valign="top">
#  <table border="0" cellspacing="0" class="mainmenu" width="100%">
#  <tr id="PreviousGA">
#  <td height="25" nowrap="">  <a class="mainmenu" href="/">Home</a>  </td>
#  <td height="25" nowrap="">  <a class="mainmenu" href="/legislation/" onblur="HM_f_PopDown('elMenu1')" onfocus="HM_f_PopUp('elMenu1',event)" onmouseout="HM_f_PopDown('elMenu1')" onmouseover="HM_f_PopUp('elMenu1',event)">Legislation &amp; Laws</a>  </td>
#  <td height="25" nowrap="">  <a class="mainmenu" href="/senate/" onblur="HM_f_PopDown('elMenu3')" onfocus="HM_f_PopUp('elMenu3',event)" onmouseout="HM_f_PopDown('elMenu3')" onmouseover="HM_f_PopUp('elMenu3',event)">Senate</a>  </td>
#  <td height="25" nowrap="">  <a class="mainmenu" href="/house/" onblur="HM_f_PopDown('elMenu2')" onfocus="HM_f_PopUp('elMenu2',event)" onmouseout="HM_f_PopDown('elMenu2')" onmouseover="HM_f_PopUp('elMenu2',event)">House</a>  </td>
#  <td height="25" nowrap="">  <a class="mainmenu" href="/mylegislation/" onblur="HM_f_PopDown('elMenu4')" onfocus="HM_f_PopUp('elMenu4',event)" onmouseout="HM_f_PopDown('elMenu4')" onmouseover="HM_f_PopUp('elMenu4',event)">My Legislation</a>  </td>
#  <td height="25" nowrap="">  <a class="mainmenu" href="/sitemap.asp">Site Map</a>  </td>
#  <td align="right" height="25" width="99%">
#
#              </td>
#  </tr>
#  </table>
#  </td>
#  </tr>, <tr id="PreviousGA">
#  <td height="25" nowrap="">  <a class="mainmenu" href="/">Home</a>  </td>
#  <td height="25" nowrap="">  <a class="mainmenu" href="/legislation/" onblur="HM_f_PopDown('elMenu1')" onfocus="HM_f_PopUp('elMenu1',event)" onmouseout="HM_f_PopDown('elMenu1')" onmouseover="HM_f_PopUp('elMenu1',event)">Legislation &amp; Laws</a>  </td>
#  <td height="25" nowrap="">  <a class="mainmenu" href="/senate/" onblur="HM_f_PopDown('elMenu3')" onfocus="HM_f_PopUp('elMenu3',event)" onmouseout="HM_f_PopDown('elMenu3')" onmouseover="HM_f_PopUp('elMenu3',event)">Senate</a>  </td>
#  <td height="25" nowrap="">  <a class="mainmenu" href="/house/" onblur="HM_f_PopDown('elMenu2')" onfocus="HM_f_PopUp('elMenu2',event)" onmouseout="HM_f_PopDown('elMenu2')" onmouseover="HM_f_PopUp('elMenu2',event)">House</a>  </td>
#  <td height="25" nowrap="">  <a class="mainmenu" href="/mylegislation/" onblur="HM_f_PopDown('elMenu4')" onfocus="HM_f_PopUp('elMenu4',event)" onmouseout="HM_f_PopDown('elMenu4')" onmouseover="HM_f_PopUp('elMenu4',event)">My Legislation</a>  </td>
#  <td height="25" nowrap="">  <a class="mainmenu" href="/sitemap.asp">Site Map</a>  </td>
#  <td align="right" height="25" width="99%">
#
#              </td>
#  </tr>, <tr>
#  <td valign="top"><br/>
#  <table border="0" cellpadding="0" cellspacing="2" class="sidemenu" id="PreviousGA" width="140"><tr><td><a href="/previousga.asp">Previous General Assemblies</a></td></tr></table></td><td class="verticalline" width="1"><img height="1" src="/images/1ptrans.gif" width="1"/></td><td align="left" valign="top" width="99%"><table align="left" border="0" width="490"><tr><td width="100%"><br/>
#  <!-- End Body Start -->
#  <!--Begin Custom Page Content -->
#  <form action="default.asp" method="get" name="member">
#  <input name="sortby" type="hidden" value=""/>
#  <input name="sortbyformer" type="hidden" value=""/>
#  <input name="sortbyGA" type="hidden" value=""/>
#  <table border="0" cellpadding="3" cellspacing="1" width="100%">
#  <tr><td colspan="5">
#  <span class="heading">Illinois State Senators</span>
#  <span class="italics">  98th  General Assembly</span><br/>
#  <!-- 3/2/09 temp comment out until fixed for GA specific-->
#  <!-- add 97th ga currently no info -->
#  <a href="98GA_Senate_Leadership.pdf">Leadership</a> <a href="98th_Senate_Officers.pdf">Officers</a> <a href="98GA_Senate_Seating_Chart.pdf">Senate Seating Chart</a>  <span class="content"><b>Democrats:</b> 40   <b>Republicans:</b> 19</span><br/>
#  </td></tr>
#  <tr>
#  <td class="header" width="45%"><a class="filetab" href="javascript:Sort('LastName','',98);" title="Sort by Senator">Senator</a></td>
#  <td align="center" class="header" width="15%">Bills</td>
#  <td align="center" class="header" width="10%">Committees</td>
#  <td align="center" class="header" width="15%"><a class="filetab" href="javascript:Sort('DistrictNumber','',98);" title="Sort by District">District</a></td>
#  <td align="center" class="header" width="15%"><a class="filetab" href="javascript:Sort('Party','',98);" title="Sort by Party">Party</a></td>
#  </tr>
#  <tr><td bgcolor="white" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=1911">Pamela J. Althoff</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=1911">Bills</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=1911">Committees</a></td><td align="center" bgcolor="white" class="detail" width="15%">32</td><td align="center" bgcolor="white" class="detail" width="15%">R</td></tr><tr><td bgcolor="EBEBEB" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=2018">Jason A. Barickman</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=2018">Bills</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=2018">Committees</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%">53</td><td align="center" bgcolor="EBEBEB" class="detail" width="15%">R</td></tr><tr><td bgcolor="white" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=2272">Scott M Bennett</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=2272">Bills</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=2272">Committees</a></td><td align="center" bgcolor="white" class="detail" width="15%">52</td><td align="center" bgcolor="white" class="detail" width="15%">D</td></tr><tr><td bgcolor="EBEBEB" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=2022">Jennifer Bertino-Tarrant</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=2022">Bills</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=2022">Committees</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%">49</td><td align="center" bgcolor="EBEBEB" class="detail" width="15%">D</td></tr><tr><td bgcolor="white" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=2020">Daniel Biss</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=2020">Bills</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=2020">Committees</a></td><td align="center" bgcolor="white" class="detail" width="15%">9</td><td align="center" bgcolor="white" class="detail" width="15%">D</td></tr><tr><td bgcolor="EBEBEB" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=1948">Tim Bivins</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=1948">Bills</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=1948">Committees</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%">45</td><td align="center" bgcolor="EBEBEB" class="detail" width="15%">R</td></tr><tr><td bgcolor="white" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=1880">William E. Brady</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=1880">Bills</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=1880">Committees</a></td><td align="center" bgcolor="white" class="detail" width="15%">44</td><td align="center" bgcolor="white" class="detail" width="15%">R</td></tr><tr><td bgcolor="EBEBEB" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=2023">Melinda Bush</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=2023">Bills</a></td><td ali ...
#  </table>
#  </form>
#  <!--End Custom Page Content-->
#  <!--Begin Page End-->
#  </td></tr>
#  <tr id="PreviousGA">
#  <td>
#  <table align="center" border="0" cellpadding="0" cellspacing="0" class="footer" width="100%">
#  <tr>
#  <td align="center" colspan="2"><hr color="navy" noshade="True"/>
#  <a class="footer" href="/" title="View the General Assembly web site home page">Home</a> |
#        <a class="footer" href="/legislation/" title="View Legislation and Laws">Legislation &amp; Laws</a> |
#        <a class="footer" href="/house/default.asp" title="View information regarding House of Representatives">House</a> |
#        <a class="footer" href="/senate/default.asp" title="View information regarding Senate">Senate</a> |
#        <a class="footer" href="/mylegislation/default.asp" title="Set up customized queries, create reports for tracking, etc.">My Legislation</a> |
#        <a class="footer" href="/disclaimer.asp" title="Disclaimers regarding the Illinois General Assembly web site">Disclaimers</a> |
#        <a class="footer" href="/contact.asp" title="Contact the Illinois General Assembly Web Support Staff">Email</a>
#  </td>
#  </tr>
#  <tr>
#  <td align="center" colspan="2"><hr color="navy" noshade="True"/><br/></td>
#  </tr>
#  <tr>
#  <td align="left" class="footer" width="107">  <img alt="Legislative Information System logo" height="45" src="/images/lislogo.jpg" width="100"/></td>
#  <td align="left" class="footer" valign="top">This site is maintained for the Illinois General Assembly
#  by the<br/>Legislative Information System, 705 Stratton Building, Springfield, Illinois 62706<br/>
#  217-782-3944   217-782-2050 (TTY)
#  <br/>
#  </td>
#  </tr>
#  </table>
#  </td>
#  </tr>
#  </table>
#  <p> </p><br/>
#  </td>
#  </tr>, <tr><td><a href="/previousga.asp">Previous General Assemblies</a></td></tr>, <tr><td width="100%"><br/>
#  <!-- End Body Start -->
#  <!--Begin Custom Page Content -->
#  <form action="default.asp" method="get" name="member">
#  <input name="sortby" type="hidden" value=""/>
#  <input name="sortbyformer" type="hidden" value=""/>
#  <input name="sortbyGA" type="hidden" value=""/>
#  <table border="0" cellpadding="3" cellspacing="1" width="100%">
#  <tr><td colspan="5">
#  <span class="heading">Illinois State Senators</span>
#  <span class="italics">  98th  General Assembly</span><br/>
#  <!-- 3/2/09 temp comment out until fixed for GA specific-->
#  <!-- add 97th ga currently no info -->
#  <a href="98GA_Senate_Leadership.pdf">Leadership</a> <a href="98th_Senate_Officers.pdf">Officers</a> <a href="98GA_Senate_Seating_Chart.pdf">Senate Seating Chart</a>  <span class="content"><b>Democrats:</b> 40   <b>Republicans:</b> 19</span><br/>
#  </td></tr>
#  <tr>
#  <td class="header" width="45%"><a class="filetab" href="javascript:Sort('LastName','',98);" title="Sort by Senator">Senator</a></td>
#  <td align="center" class="header" width="15%">Bills</td>
#  <td align="center" class="header" width="10%">Committees</td>
#  <td align="center" class="header" width="15%"><a class="filetab" href="javascript:Sort('DistrictNumber','',98);" title="Sort by District">District</a></td>
#  <td align="center" class="header" width="15%"><a class="filetab" href="javascript:Sort('Party','',98);" title="Sort by Party">Party</a></td>
#  </tr>
#  <tr><td bgcolor="white" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=1911">Pamela J. Althoff</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=1911">Bills</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=1911">Committees</a></td><td align="center" bgcolor="white" class="detail" width="15%">32</td><td align="center" bgcolor="white" class="detail" width="15%">R</td></tr><tr><td bgcolor="EBEBEB" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=2018">Jason A. Barickman</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=2018">Bills</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=2018">Committees</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%">53</td><td align="center" bgcolor="EBEBEB" class="detail" width="15%">R</td></tr><tr><td bgcolor="white" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=2272">Scott M Bennett</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=2272">Bills</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=2272">Committees</a></td><td align="center" bgcolor="white" class="detail" width="15%">52</td><td align="center" bgcolor="white" class="detail" width="15%">D</td></tr><tr><td bgcolor="EBEBEB" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=2022">Jennifer Bertino-Tarrant</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=2022">Bills</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=2022">Committees</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%">49</td><td align="center" bgcolor="EBEBEB" class="detail" width="15%">D</td></tr><tr><td bgcolor="white" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=2020">Daniel Biss</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=2020">Bills</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=2020">Committees</a></td><td align="center" bgcolor="white" class="detail" width="15%">9</td><td align="center" bgcolor="white" class="detail" width="15%">D</td></tr><tr><td bgcolor="EBEBEB" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=1948">Tim Bivins</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=1948">Bills</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=1948">Committees</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%">45</td><td align="center" bgcolor="EBEBEB" class="detail" width="15%">R</td></tr><tr><td bgcolor="white" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=1880">William E. Brady</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=1880">Bills</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=1880">Committees</a></td><td align="center" bgcolor="white" class="detail" width="15%">44</td><td align="center" bgcolor="white" class="detail" width="15%">R</td></tr><tr><td bgcolor="EBEBEB" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=2023">Melinda Bush</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=2023">Bills</a></td><td ali ...
#  </table>
#  </form>
#  <!--End Custom Page Content-->
#  <!--Begin Page End-->
#  </td></tr>, <tr><td colspan="5">
#  <span class="heading">Illinois State Senators</span>
#  <span class="italics">  98th  General Assembly</span><br/>
#  <!-- 3/2/09 temp comment out until fixed for GA specific-->
#  <!-- add 97th ga currently no info -->
#  <a href="98GA_Senate_Leadership.pdf">Leadership</a> <a href="98th_Senate_Officers.pdf">Officers</a> <a href="98GA_Senate_Seating_Chart.pdf">Senate Seating Chart</a>  <span class="content"><b>Democrats:</b> 40   <b>Republicans:</b> 19</span><br/>
#  </td></tr>, <tr>
#  <td class="header" width="45%"><a class="filetab" href="javascript:Sort('LastName','',98);" title="Sort by Senator">Senator</a></td>
#  <td align="center" class="header" width="15%">Bills</td>
#  <td align="center" class="header" width="10%">Committees</td>
#  <td align="center" class="header" width="15%"><a class="filetab" href="javascript:Sort('DistrictNumber','',98);" title="Sort by District">District</a></td>
#  <td align="center" class="header" width="15%"><a class="filetab" href="javascript:Sort('Party','',98);" title="Sort by Party">Party</a></td>
#  </tr>, <tr><td bgcolor="white" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=1911">Pamela J. Althoff</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=1911">Bills</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=1911">Committees</a></td><td align="center" bgcolor="white" class="detail" width="15%">32</td><td align="center" bgcolor="white" class="detail" width="15%">R</td></tr>, <tr><td bgcolor="EBEBEB" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=2018">Jason A. Barickman</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=2018">Bills</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=2018">Committees</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%">53</td><td align="center" bgcolor="EBEBEB" class="detail" width="15%">R</td></tr>, <tr><td bgcolor="white" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=2272">Scott M Bennett</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=2272">Bills</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=2272">Committees</a></td><td align="center" bgcolor="white" class="detail" width="15%">52</td><td align="center" bgcolor="white" class="detail" width="15%">D</td></tr>, <tr><td bgcolor="EBEBEB" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=2022">Jennifer Bertino-Tarrant</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=2022">Bills</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=2022">Committees</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%">49</td><td align="center" bgcolor="EBEBEB" class="detail" width="15%">D</td></tr>, <tr><td bgcolor="white" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=2020">Daniel Biss</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=2020">Bills</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=2020">Committees</a></td><td align="center" bgcolor="white" class="detail" width="15%">9</td><td align="center" bgcolor="white" class="detail" width="15%">D</td></tr>, <tr><td bgcolor="EBEBEB" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=1948">Tim Bivins</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=1948">Bills</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=1948">Committees</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%">45</td><td align="center" bgcolor="EBEBEB" class="detail" width="15%">R</td></tr>, <tr><td bgcolor="white" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=1880">William E. Brady</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=1880">Bills</a></td><td align="center" bgcolor="white" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=1880">Committees</a></td><td align="center" bgcolor="white" class="detail" width="15%">44</td><td align="center" bgcolor="white" class="detail" width="15%">R</td></tr>, <tr><td bgcolor="EBEBEB" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=2023">Melinda Bush</a></td><td align="center" bgcolor="EBEBEB" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=2023"> ...
#  <td>
#  <table align="center" border="0" cellpadding="0" cellspacing="0" class="footer" width="100%">
#  <tr>
#  <td align="center" colspan="2"><hr color="navy" noshade="True"/>
#  <a class="footer" href="/" title="View the General Assembly web site home page">Home</a> |
#        <a class="footer" href="/legislation/" title="View Legislation and Laws">Legislation &amp; Laws</a> |
#        <a class="footer" href="/house/default.asp" title="View information regarding House of Representatives">House</a> |
#        <a class="footer" href="/senate/default.asp" title="View information regarding Senate">Senate</a> |
#        <a class="footer" href="/mylegislation/default.asp" title="Set up customized queries, create reports for tracking, etc.">My Legislation</a> |
#        <a class="footer" href="/disclaimer.asp" title="Disclaimers regarding the Illinois General Assembly web site">Disclaimers</a> |
#        <a class="footer" href="/contact.asp" title="Contact the Illinois General Assembly Web Support Staff">Email</a>
#  </td>
#  </tr>
#  <tr>
#  <td align="center" colspan="2"><hr color="navy" noshade="True"/><br/></td>
#  </tr>
#  <tr>
#  <td align="left" class="footer" width="107">  <img alt="Legislative Information System logo" height="45" src="/images/lislogo.jpg" width="100"/></td>
#  <td align="left" class="footer" valign="top">This site is maintained for the Illinois General Assembly
#  by the<br/>Legislative Information System, 705 Stratton Building, Springfield, Illinois 62706<br/>
#  217-782-3944   217-782-2050 (TTY)
#  <br/>
#  </td>
#  </tr>
#  </table>
#  </td>
#  </tr>, <tr>
#  <td align="center" colspan="2"><hr color="navy" noshade="True"/>
#  <a class="footer" href="/" title="View the General Assembly web site home page">Home</a> |
#        <a class="footer" href="/legislation/" title="View Legislation and Laws">Legislation &amp; Laws</a> |
#        <a class="footer" href="/house/default.asp" title="View information regarding House of Representatives">House</a> |
#        <a class="footer" href="/senate/default.asp" title="View information regarding Senate">Senate</a> |
#        <a class="footer" href="/mylegislation/default.asp" title="Set up customized queries, create reports for tracking, etc.">My Legislation</a> |
#        <a class="footer" href="/disclaimer.asp" title="Disclaimers regarding the Illinois General Assembly web site">Disclaimers</a> |
#        <a class="footer" href="/contact.asp" title="Contact the Illinois General Assembly Web Support Staff">Email</a>
#  </td>
#  </tr>, <tr>
#  <td align="center" colspan="2"><hr color="navy" noshade="True"/><br/></td>
#  </tr>, <tr>
#  <td align="left" class="footer" width="107">  <img alt="Legislative Information System logo" height="45" src="/images/lislogo.jpg" width="100"/></td>
#  <td align="left" class="footer" valign="top">This site is maintained for the Illinois General Assembly
#  by the<br/>Legislative Information System, 705 Stratton Building, Springfield, Illinois 62706<br/>
#  217-782-3944   217-782-2050 (TTY)
#  <br/>
#  </td>
#  </tr>]

# %% [markdown]
# But remember, `find_all` gets all the elements with the `tr` tag. We can use smart CSS selectors to get only the rows we want.

# %%
# returns every ‘tr tr tr’ css selector in the page
rows = soup.select('tr tr tr')
print(rows[2].prettify())
# Out:
# <tr>
#  <td bgcolor="white" class="detail" width="40%">
#   <a href="/senate/Senator.asp?GA=98&amp;MemberID=1911">
#    Pamela J. Althoff
#   </a>
#  </td>
#  <td align="center" bgcolor="white" class="detail" width="15%">
#   <a href="SenatorBills.asp?GA=98&amp;MemberID=1911">
#    Bills
#   </a>
#  </td>
#  <td align="center" bgcolor="white" class="detail" width="15%">
#   <a href="SenCommittees.asp?GA=98&amp;MemberID=1911">
#    Committees
#   </a>
#  </td>
#  <td align="center" bgcolor="white" class="detail" width="15%">
#   32
#  </td>
#  <td align="center" bgcolor="white" class="detail" width="15%">
#   R
#  </td>
# </tr>

# %% [markdown]
# We can use the `select` method on anything. Let's say we want to find everything with the CSS selector `td.detail` in an item of the list we created above.

# %%
# select only those 'td' tags with class 'detail'
row = rows[2]
detailCells = row.select('td.detail')
len(detailCells)
# Out:
# 5

# %%
detailCells[1].find("a").get("href")
# Out:
# 'SenatorBills.asp?GA=98&MemberID=1911'

# %% [markdown]
# Most of the time, we're interested in the actual **text** of a website, not its tags. Remember, to get the text of an HTML element, use the `text` member.

# %%
# Keep only the text in each of those cells
rowData = [cell.text for cell in detailCells]

# %%
rowData
# Out:
# ['Pamela J. Althoff', 'Bills', 'Committees', '32', 'R']

# %% [markdown]
# Now we can combine the beautifulsoup tools with our basic python skills to scrape an entire web page.

# %%
# check em out
print(rowData[0]) # Name
print(rowData[3]) # district
print(rowData[4]) # party
# Out:
# Pamela J. Althoff
# 32
# R

# %% [markdown]
# ## 2.3 Loop it all together
#
# Let's use a for loop to get 'em all!

# %%
# make a GET request
req = requests.get('http://www.ilga.gov/senate/default.asp?GA=98')

# read the content of the server’s response
src = req.text

# soup it
soup = BeautifulSoup(src, "lxml")

# Create empty list to store our data
members = []

# returns every ‘tr tr tr’ css selector in the page
rows = soup.select('tr tr tr')

# loop through all rows
for row in rows:
    # select only those 'td' tags with class 'detail'
    detailCells = row.select('td.detail')
    
    # get rid of junk rows
    if len(detailCells) is not 5: 
        continue
        
    # Keep only the text in each of those cells
    rowData = [cell.text for cell in detailCells]
    
    # Collect information
    name = rowData[0]
    district = int(rowData[3])
    party = rowData[4]
    
    # Store in a tuple
    tup = (name,district,party)
    
    # Append to list
    members.append(tup)

# %%
len(members)
# Out:
# 61

# %%
for m in members:
    print(m)
# Out:
# ('Pamela J. Althoff', 32, 'R')
# ('Jason A. Barickman', 53, 'R')
# ('Scott M Bennett', 52, 'D')
# ('Jennifer Bertino-Tarrant', 49, 'D')
# ('Daniel Biss', 9, 'D')
# ('Tim Bivins', 45, 'R')
# ('William E. Brady', 44, 'R')
# ('Melinda Bush', 31, 'D')
# ('James F. Clayborne, Jr.', 57, 'D')
# ('Jacqueline Y. Collins', 16, 'D')
# ('Michael Connelly', 21, 'R')
# ('John J. Cullerton', 6, 'D')
# ('Thomas Cullerton', 23, 'D')
# ('Bill Cunningham', 18, 'D')
# ('William Delgado', 2, 'D')
# ('Kirk W. Dillard', 24, 'R')
# ('Dan Duffy', 26, 'R')
# ('Gary Forby', 59, 'D')
# ('Michael W. Frerichs', 52, 'D')
# ('William R. Haine', 56, 'D')
# ('Don Harmon', 39, 'D')
# ('Napoleon Harris, III', 15, 'D')
# ('Michael E. Hastings', 19, 'D')
# ('Linda Holmes', 42, 'D')
# ('Mattie Hunter', 3, 'D')
# ('Toi W. Hutchinson', 40, 'D')
# ('Mike Jacobs', 36, 'D')
# ('Emil Jones, III', 14, 'D')
# ('David Koehler', 46, 'D')
# ('Dan Kotowski', 28, 'D')
# ('Darin M. LaHood', 37, 'R')
# ('Steven M. Landek', 12, 'D')
# ('Kimberly A. Lightford', 4, 'D')
# ('Terry Link', 30, 'D')
# ('David S. Luechtefeld', 58, 'R')
# ('Andy Manar', 48, 'D')
# ('Iris Y. Martinez', 20, 'D')
# ('Wm. Sam McCann', 50, 'R')
# ('Kyle McCarter', 54, 'R')
# ('Karen McConnaughay', 33, 'R')
# ('Pat McGuire', 43, 'D')
# ('Julie A. Morrison', 29, 'D')
# ('John G. Mulroe', 10, 'D')
# ('Antonio Muñoz', 1, 'D')
# ('Matt Murphy', 27, 'R')
# ('Michael Noland', 22, 'D')
# ('Chris Nybo', 24, 'R')
# ('Jim Oberweis', 25, 'R')
# ('Christine Radogno', 41, 'R')
# ('Kwame Raoul', 13, 'D')
# ('Sue Rezin', 38, 'R')
# ('Dale A. Righter', 55, 'R')
# ('Chapin Rose', 51, 'R')
# ('Martin A. Sandoval', 11, 'D')
# ('Ira I. Silverstein', 8, 'D')
# ('Steve Stadelman', 34, 'D')
# ('Heather A. Steans', 7, 'D')
# ('John M. Sullivan', 47, 'D')
# ('Dave Syverson', 35, 'R')
# ('Donne E. Trotter', 17, 'D')
# ('Patricia Van Pelt', 5, 'D')

# %% [markdown]
# ## Challege 3: Get HREF element pointing to members' bills.
#
# The code above retrieves information on:
#
#     - the senator's name
#     - their district number
#     - and their party
#
# We now want to retrieve the URL for each senator's list of bills. The format for the list of bills for a given senator is:
#
# http://www.ilga.gov/senate/SenatorBills.asp + ? + GA=98 + &MemberID=**_memberID_** + &Primary=True
#
# to get something like:
#
# http://www.ilga.gov/senate/SenatorBills.asp?MemberID=1911&GA=98&Primary=True
#
# You should be able to see that, unfortunately, _memberID_ is not currently something pulled out in our scraping code.
#
# Your initial task is to modify the code above so that we also **retrieve the full URL which points to the corresponding page of primary-sponsored bills**, for each member, and return it along with their name, district, and party.
#
# Tips:
#
# * To do this, you will want to get the appropriate anchor element (`<a>`) in each legislator's row of the table. You can again use the `.select()` method on the `row` object in the loop to do this — similar to the command that finds all of the `td.detail` cells in the row. Remember that we only want the link to the legislator's bills, not the committees or the legislator's profile page.
# * The anchor elements' HTML will look like `<a href="/senate/Senator.asp/...">Bills</a>`. The string in the `href` attribute contains the **relative** link we are after. You can access an attribute of a BeatifulSoup `Tag` object the same way you access a Python dictionary: `anchor['attributeName']`. (See the <a href="http://www.crummy.com/software/BeautifulSoup/bs4/doc/#tag">documentation</a> for more details).
# * NOTE: There are a _lot_ of different ways to use BeautifulSoup to get things done; whatever you need to do to pull that HREF out is fine. Posting on the etherpad is recommended for discussing different strategies.
#
# I've started out the code for you. Fill it in where it says `#YOUR CODE HERE` (Save the path into an object called `full_path`

# %%
def get_members(url):

    # make a GET request
    req = requests.get(url)

    # read the content of the server’s response
    src = req.text

    # soup it
    soup = BeautifulSoup(src, "lxml")

    # Create empty list to store our data
    members = []

    # returns every ‘tr tr tr’ css selector in the page
    rows = soup.select('tr tr tr')

    # loop through all rows
    for row in rows:
        # select only those 'td' tags with class 'detail'
        detailCells = row.select('td.detail')

        # get rid of junk rows
        if len(detailCells) is not 5: 
            continue

        url_extension = detailCells[1].find("a").get("href")

        # Keep only the text in each of those cells
        rowData = [cell.text for cell in detailCells]

        # Collect information
        name = rowData[0]
        district = int(rowData[3])
        party = rowData[4]

        # YOUR CODE HERE.

        # stuff here
        # http://www.ilga.gov/senate/SenatorBills.asp?MemberID=1911&GA=98&Primary=True

        base = "http://www.ilga.gov/senate/"
        full_path = base + url_extension 

        # Store in a tuple
        tup = (name, district, party, full_path)

        # Append to list
        members.append(tup)

# %%
# Uncomment to test 

members[:5]
# Out:
# [('Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911'),
#  ('Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018'),
#  ('Scott M Bennett',
#   52,
#   'D',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2272'),
#  ('Jennifer Bertino-Tarrant',
#   49,
#   'D',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2022'),
#  ('Daniel Biss',
#   9,
#   'D',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2020')]

# %% [markdown]
# ## Challenge 4: Make a function
#
# Turn the code above into a function that accepts a URL, scrapes the URL for its senators, and returns a list of tuples containing information about each senator.

# %%
# YOUR FUNCTION HERE

def get_members(url):
    # make a GET request
    req = requests.get(url)

    # read the content of the server’s response
    src = req.text

    # soup it
    soup = BeautifulSoup(src, "lxml")

    # Create empty list to store our data
    members = []

    # returns every ‘tr tr tr’ css selector in the page
    rows = soup.select('tr tr tr')

    # loop through all rows
    for row in rows:
        # select only those 'td' tags with class 'detail'
        detailCells = row.select('td.detail')

        # get rid of junk rows
        if len(detailCells) is not 5: 
            continue

        url_extension = detailCells[1].find("a").get("href")

        # Keep only the text in each of those cells
        rowData = [cell.text for cell in detailCells]

        # Collect information
        name = rowData[0]
        district = int(rowData[3])
        party = rowData[4]

        # YOUR CODE HERE.

        # stuff here
        # http://www.ilga.gov/senate/SenatorBills.asp?MemberID=1911&GA=98&Primary=True

        base = "http://www.ilga.gov/senate/"
        full_path = base + url_extension 

        # Store in a tuple
        tup = (name, district, party, full_path)

        # Append to list
        members.append(tup)
        
    return members

# %%
# Uncomment to test you3 code!

senateMembers = get_members('http://www.ilga.gov/senate/default.asp?GA=98')
len(senateMembers)
# Out:
# 61

# %%
senateMembers[4]
# Out:
# ('Daniel Biss',
#  9,
#  'D',
#  'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2020')

# %% [markdown]
# # Part 3: Scrape Bills
# ****
#
# ## 3.1 Writing a Scraper Function
#
# Now we want to scrape the webpages corresponding to bills sponsored by each bills.
#
# Write a function called `get_bills(url)` to parse a given Bills URL. This will involve:
#
#   - requesting the URL using the <a href="http://docs.python-requests.org/en/latest/">`requests`</a> library
#   - using the features of the `BeautifulSoup` library to find all of the `<td>` elements with the class `billlist`
#   - return a _list_ of tuples, each with:
#       - description (2nd column)
#       - chamber (S or H) (3rd column)
#       - the last action (4th column)
#       - the last action date (5th column)
#
# I've started the function for you. Fill in the rest.

# %%
# COMPLETE THIS FUNCTION
def get_bills(url):
    src = requests.get(url).text
    soup = BeautifulSoup(src, "lxml")
    rows = soup.select('tr tr tr')

    bills = []
    for row in rows:
        
        detailCells = row.findAll('td')
        rowData = [cell.text for cell in detailCells]
        
        if len(rowData) == 6:
        
            bill_id = rowData[0]
            description = rowData[2]
            chamber = rowData[3]
            last_action = rowData[4]
            last_action_date = rowData[5]

            tup = (bill_id, description, chamber, last_action, last_action_date)
            bills.append(tup)
            
    bills = bills[1:]

    return(bills)

# %%
# uncomment to test your code:
test_url = senateMembers[0][3]
get_bills(test_url)[0:5]
# Out:
# [('SB2', 'STATE GOVERNMENT-TECH', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB9',
#   'PUBLIC UTIL-PERFORMANCE-BASED',
#   'S',
#   'Public Act . . . . . . . . . 98-0015',
#   '5/23/2013'),
#  ('SB27', 'MEDICAID BUDGET NOTE ACT', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB28',
#   'HOMELESS VETERANS SHELTER ACT',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB29', 'ROAD FUND-NO TRANSFERS', 'S', 'Session Sine Die', '1/13/2015')]

# %% [markdown]
# ## 3.2 Get all the bills
#
# Finally, create a dictionary `bills_dict` which maps a district number (the key) onto a list_of_bills (the value) eminating from that district. You can do this by looping over all of the senate members in `members_dict` and calling `get_bills()` for each of their associated bill URLs.
#
# NOTE: please call the function `time.sleep(0.5)` for each iteration of the loop, so that we don't destroy the state's web site.

# %%
# YOUR CODE HERE

# %%
from random import randint
import time

senators_bills = {}

for senator in senateMembers:
    senators_bills[senator[0]] = get_bills(senator[3])
    
    time.sleep(randint(1,3))

# %%
senators_bills.keys()
# Out:
# dict_keys(['William Delgado', 'Michael W. Frerichs', 'Michael Connelly', 'John G. Mulroe', 'Donne E. Trotter', 'Scott M Bennett', 'Chris Nybo', 'Dan Duffy', 'Dave Syverson', 'William E. Brady', 'Terry Link', 'Patricia Van Pelt', 'Matt Murphy', 'Ira I. Silverstein', 'Julie A. Morrison', 'John J. Cullerton', 'Antonio Muñoz', 'Mike Jacobs', 'Jason A. Barickman', 'Gary Forby', 'Jim Oberweis', 'David Koehler', 'Toi W. Hutchinson', 'Michael Noland', 'Mattie Hunter', 'Heather A. Steans', 'James F. Clayborne, Jr.', 'Kimberly A. Lightford', 'Linda Holmes', 'Darin M. LaHood', 'Karen McConnaughay', 'Kwame Raoul', 'Chapin Rose', 'Melinda Bush', 'David S. Luechtefeld', 'Pamela J. Althoff', 'William R. Haine', 'Jennifer Bertino-Tarrant', 'Christine Radogno', 'John M. Sullivan', 'Michael E. Hastings', 'Jacqueline Y. Collins', 'Kirk W. Dillard', 'Tim Bivins', 'Napoleon Harris, III', 'Thomas Cullerton', 'Daniel Biss', 'Martin A. Sandoval', 'Wm. Sam McCann', 'Sue Rezin', 'Kyle McCarter', 'Don Harmon', 'Pat McGuire', 'Bill Cunningham', 'Dan Kotowski', 'Steve Stadelman', 'Andy Manar', 'Dale A. Righter', 'Iris Y. Martinez', 'Emil Jones, III', 'Steven M. Landek'])

# %%
senators_bills["William Delgado"]
# Out:
# [('SB10',
#   'CIVIL LAW-TECH',
#   'S',
#   'Public Act . . . . . . . . . 98-0597',
#   '11/20/2013'),
#  ('SB26',
#   'MEDICAID-HEALTH BENEFITS SRVCE',
#   'S',
#   'Public Act . . . . . . . . . 98-0104',
#   '7/22/2013'),
#  ('SB34', 'HLTH BENEFITS EX-ADMIN', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB66', 'RIVERBOATS-SUPPLIERS-CHIPS', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB68', 'MINIMUM WAGE INCREASES', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB103', 'UTILITES-RENEWABLE ENERGY', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB121',
#   'AFRICAN-AMERICAN FAMILY COMM',
#   'S',
#   'Public Act . . . . . . . . . 98-0693',
#   '7/2/2014'),
#  ('SB217',
#   'TRAINING EMPLOYMENT PGM ACT',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB228', 'STATE GOVERNMENT-TECH', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB229',
#   'GUBERNATORIAL BDS-DEMOGRAPHIC',
#   'S',
#   'Public Act . . . . . . . . . 98-1087',
#   '8/26/2014'),
#  ('SB336',
#   'REHAB/REVITALIZ TAX CREDIT ACT',
#   'S',
#   'Public Act . . . . . . . . . 98-0789',
#   '7/25/2014'),
#  ('SB506',
#   'COUNTIES-CORONER-CONFLICTS',
#   'S',
#   'Public Act . . . . . . . . . 98-0812',
#   '8/1/2014'),
#  ('SB588', 'EDUCATION-TECH', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB589', 'EDUCATION-TECH', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB590', 'EDUCATION-TECH', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB638', 'REGULATION-TECH', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB742',
#   'PUB AID-PERS NEEDS ALLOWANCE',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB856', 'SAFETY-TECH', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB923',
#   'VEH CD-AUTOMATED ENFORCEMENT',
#   'S',
#   'Public Act . . . . . . . . . 98-0556',
#   '8/27/2013'),
#  ('SB1003', 'CRIMINAL LAW-TECH', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB1011', 'CRIMINAL LAW-TECH', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB1190', 'FAMILY CARE PROVIDER ACT', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB1191',
#   'CHILD CARE-UNSAFE PRODUCT LIST',
#   'S',
#   'Public Act . . . . . . . . . 98-0082',
#   '7/15/2013'),
#  ('SB1192',
#   'CD CORR-JUVENILE AFTERCARE',
#   'S',
#   'Public Act . . . . . . . . . 98-0558',
#   '8/27/2013'),
#  ('SB1210',
#   'HOMELESS BILL OF RIGHTS-NEW',
#   'S',
#   'Public Act . . . . . . . . . 98-0516',
#   '8/22/2013'),
#  ('SB1440', '$DPH-POISON CENTER', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB1448',
#   'ENDOW ILLINOIS TAX CREDIT ACT',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB1451',
#   '$DPH-LOCAL HLTH PROTECTION',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB1452', 'CRIMINAL LAW-TECH', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB1453', 'CRIMINAL LAW-TECH', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB1454',
#   'CONTROLLED SUBSTANCES-VARIOUS',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB1455',
#   'SOCIAL WORK-CONTINUING ED.',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB1476',
#   'NURS HOME-STAFF RATIO-MEDICAID',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB1550',
#   'SCH CD-SPEC ED-TRANSITION SERV',
#   'S',
#   'Public Act . . . . . . . . . 98-0517',
#   '8/22/2013'),
#  ('SB1565',
#   'PROBATE: SHORT-TERM GUARDIAN',
#   'S',
#   'Public Act . . . . . . . . . 98-0568',
#   '8/27/2013'),
#  ('SB1566', 'LIQUOR-TECH', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB1567',
#   'MENTAL HEALTH FIRST AID TRAIN',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB1568',
#   'WAGE PAYMENT AND COLLECTION',
#   'S',
#   'Public Act . . . . . . . . . 98-0527',
#   '8/23/2013'),
#  ('SB1569', 'LOCAL GOVERNMENT-TECH', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB1570', 'EDUCATION-TECH', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB1571',
#   'SCH CD-CHI-CLOSURE MORATORIUM',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB1572',
#   'SCH CD-REPORT-CHICAGO PRACTICE',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB1573', 'EDUCATION-TECH', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB1574', 'EDUCATION-TECH', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB1602',
#   'FORECLOSURES: OCCUPANT RIGHTS',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB1626',
#   'PROVIDER COPAY EQUITY ACT-TECH',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB1639',
#   'ANIMAL WELFARE-PUPPY LEMON LAW',
#   'S',
#   'Public Act . . . . . . . . . 98-0509',
#   '8/19/2013'),
#  ('SB1640',
#   'MULTIPLE SCLEROSIS TASK FORCE',
#   'S',
#   'Public Act . . . . . . . . . 98-0530',
#   '8/23/2013'),
#  ('SB1655',
#   'DD REGULATORY ADVISORY BOARD',
#   'S',
#   'Public Act . . . . . . . . . 98-0531',
#   '8/23/2013'),
#  ('SB1659',
#   'INC TX-EX OFFENDER',
#   'S',
#   'Public Act . . . . . . . . . 98-0165',
#   '8/5/2013'),
#  ('SB1664',
#   'PRIVATE DETECTIVES-SUNSET',
#   'S',
#   'Public Act . . . . . . . . . 98-0045',
#   '6/28/2013'),
#  ('SB1666',
#   'GENETICALLY ENGINEERED FOOD',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB1702',
#   'SCH CD-DOMESTIC/SEX VIOLENCE',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB1708',
#   'DOMESTIC WORKER BILL OF RIGHTS',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB1728',
#   'FORCLOSURES-HOMEOWNER PROTECT',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB1733', 'COMPLEX NEEDS PATIENT ACT', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB1734',
#   'PUB AID-WHEELCHAIR REPAIRS',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB1767', 'STATE GOVERNMENT-TECH', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB1792',
#   'ARCHITECTURE-QUALIFICATIONS',
#   'S',
#   'Public Act . . . . . . . . . 98-0288',
#   '8/9/2013'),
#  ('SB1807',
#   'MEDICAID PRIOR AUTHORIZATION',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB1808',
#   'MEDICAID-APR-DRG PAYMNT SYSTM',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB1809',
#   'IDPH-MEDICAID PENALTY PAYMENTS',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB1811', '$DHS-YOUTHBUILD', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB1857', 'COURTS-TECH', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB1872',
#   'CRIM CD-PROSTITUTION-PENALTY',
#   'S',
#   'Public Act . . . . . . . . . 98-0538',
#   '8/23/2013'),
#  ('SB2206',
#   'EDGE-TIF-BUSINESSES POST SIGN',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB2208', 'PUBLIC AID-TECH', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB2215', 'PUBLIC AID-TECH', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB2267', 'CRIM CD-FIREARM OFFENSES', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB2319', 'DHS-TANF-ASSET DISREGARDS', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB2555',
#   '$STATE BOARD OF EDUCATION',
#   'S',
#   'Public Act . . . . . . . . . 98-0034',
#   '6/27/2013'),
#  ('SB2576',
#   '$AGING-DHS-COMM CARE&HOME SRVC',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB2580',
#   '$AGING-COMM CARE-CAPITATD CARE',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB2581',
#   '$DHS-CHILD CARE-EMPLY&TRAINING',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB2582',
#   '$DHS-HOME SERVICES PROGRAM',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB2585', 'DHFS-INS-RX DRUGS-FORMS', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB2586',
#   'MENTAL HLTH SYSTEM PLANNING',
#   'S',
#   'Public Act . . . . . . . . . 98-0878',
#   '8/11/2014'),
#  ('SB2603', '$VARIOUS-PERSONAL SERV', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB2604',
#   'DIRECT SERVICE PERSONNEL-WAGES',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB2611',
#   'MEDICAID-ANTIPSYCHOTIC MEDS',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB2627',
#   'SCH CD-ST CHARTER SCH COMM',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB2630',
#   'CUSTODY-NONIMMIGRANT RIGHTS',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB2636',
#   'CANNABIS PILOT PRGM-EPILEPSY',
#   'S',
#   'Public Act . . . . . . . . . 98-0775',
#   '7/21/2014'),
#  ('SB2670', 'HEPATITIS C SCREENING ACT', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB2674', 'LOCAL GOVT-POISON CONTROL', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB2692',
#   'CHILD CARE-INCOME THRESHOLDS',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB2694',
#   'POSTING INFORMATION-INTERNET',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB2699',
#   'ADVANCED PLACEMENT EXAM-CREDIT',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB2711',
#   'FINANCE-STATE BD OF EDU-GRANTS',
#   'S',
#   'Public Act . . . . . . . . . 98-1147',
#   '12/31/2014'),
#  ('SB2735',
#   'PUB AID-AABD-REFUGEES/ASYLEES',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB2747',
#   'SCHOOL SECURITY TASK FORCE',
#   'S',
#   'Public Act . . . . . . . . . 98-0695',
#   '7/3/2014'),
#  ('SB2758',
#   'SECURE CHOICE SAVINGS PROGRAM',
#   'S',
#   'Public Act . . . . . . . . . 98-1150',
#   '1/5/2015'),
#  ('SB2773',
#   'DHFS-LONG-TERM SRVC TASK FORCE',
#   'S',
#   'Public Act . . . . . . . . . 98-0825',
#   '8/1/2014'),
#  ('SB2775',
#   'SCH CD-TRANSPORT-SAFE PASSAGE',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB2776',
#   'LLC-ARTICLES-REDUCE FILING FEE',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB2779',
#   'SCH CD-CHARTER SCH-REFERENDUM',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB2793',
#   'SCH CD-SCH REPORT CARD-DISCIP',
#   'S',
#   'Public Act . . . . . . . . . 98-1102',
#   '8/26/2014'),
#  ('SB2797',
#   'VIDEO GAMING-EXCLUSION LIST',
#   'H',
#   'Third Reading - Short Debate - Lost 019-089-006',
#   '5/22/2014'),
#  ('SB2801',
#   'CRIM PRO-UNFIT DEFENDANTS',
#   'S',
#   'Public Act . . . . . . . . . 98-1025',
#   '8/22/2014'),
#  ('SB2865',
#   'INC TX-EARNED INCOME CREDIT',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB2870',
#   'SCH CD-BULLYING PREVENTION',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB2934',
#   'IEMA-GRANTS TO SCHOOLS',
#   'S',
#   'Public Act . . . . . . . . . 98-0664',
#   '6/23/2014'),
#  ('SB2945',
#   'SCH CD-SPECIAL ED-PROVIDR-RATE',
#   'S',
#   'Public Act . . . . . . . . . 98-0636',
#   '6/6/2014'),
#  ('SB2968',
#   'NURSING HOME CLOSURE-NOTICE',
#   'S',
#   'Public Act . . . . . . . . . 98-0834',
#   '8/1/2014'),
#  ('SB2988',
#   'MED CANNABIS-DISPENSER-ZONING',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB2989',
#   'SCH CD-PSYCHOLOGIST-PRINCIPAL',
#   'S',
#   'Public Act . . . . . . . . . 98-0947',
#   '8/15/2014'),
#  ('SB2990',
#   '$DPH-LOCAL HLTH PROTECTION',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB2993',
#   'CRIM CD&CD CORR-SENTENCING',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB3004', 'SCH CD-STUDENT DISCIPLINE', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB3007', 'CRIMINAL LAW-TECH', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB3009',
#   'DCFS ANNUAL PROGRESS REPORT',
#   'S',
#   'Public Act . . . . . . . . . 98-0839',
#   '8/1/2014'),
#  ('SB3028',
#   'NURS HOME-EMERGENCY TRANSFER',
#   'S',
#   'Public Act . . . . . . . . . 98-1172',
#   '1/12/2015'),
#  ('SB3030', 'EDUCATION-TECH', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB3035',
#   'NURS HOME-RECEIVER REIMBURSE',
#   'S',
#   'Public Act . . . . . . . . . 98-0765',
#   '7/16/2014'),
#  ('SB3048',
#   'HLTH CARE PROVIDER-DEFINITION',
#   'S',
#   'Public Act . . . . . . . . . 98-0841',
#   '8/1/2014'),
#  ('SB3049',
#   'PROTECTION OF WILDLIFE',
#   'S',
#   'Public Act . . . . . . . . . 98-1033',
#   '8/25/2014'),
#  ('SB3050',
#   'VETERINARIANS-INVESTIGATIONS',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB3092',
#   'EDUC DATA SYSTEM-PERSONAL INFO',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB3124',
#   'DHFS-PERSONAL NEEDS-INCREASES',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB3134', 'CTY CD-CORONER DUTIES', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB3147',
#   'HOUSING OPP AREA-SUNSET EXT',
#   'S',
#   'Public Act . . . . . . . . . 98-0957',
#   '8/15/2014'),
#  ('SB3166', 'EDUCATION-TECH', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB3171',
#   'MEDICAID-PODIATRY SERVICES',
#   'S',
#   'Public Act . . . . . . . . . 98-1166',
#   '1/9/2015'),
#  ('SB3180', 'GOV BDS-DEMOGRAPHIC INFO', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB3216',
#   'TANF-CHILD SUPPORT DISREGARDS',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB3225',
#   'POLICE TRAINING ACT-VETERANS',
#   'S',
#   'Public Act . . . . . . . . . 98-0960',
#   '8/15/2014'),
#  ('SB3230', 'FRACKING TAX', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB3256',
#   'MEDICAID-ID/DD-BILLING CLAIMS',
#   'S',
#   'Public Act . . . . . . . . . 98-0963',
#   '8/15/2014'),
#  ('SB3257',
#   'MEDICAID-PERSONAL NEEDS-ID/DD',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB3274',
#   'SCH CD-HIGHLY QUALIFIED TEACHR',
#   'S',
#   'Public Act . . . . . . . . . 98-0860',
#   '8/4/2014'),
#  ('SB3277', 'PHARMACISTS-MENINGITIS', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB3283',
#   'DCFS-CHILD CUSTODY-FICTIVE KIN',
#   'S',
#   'Public Act . . . . . . . . . 98-0846',
#   '8/1/2014'),
#  ('SB3287',
#   'WORK COMP-WHOLLY OWNED SVC ORG',
#   'S',
#   'Public Act . . . . . . . . . 98-0633',
#   '6/5/2014'),
#  ('SB3313',
#   '9-1-1 DIALING',
#   'S',
#   'Public Act . . . . . . . . . 98-0875',
#   '8/11/2014'),
#  ('SB3326',
#   'HYDRAULIC FRAC-LOCAL CONSENT',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB3327',
#   'FRACKING-SETBACK ADJUSTMENT',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB3328', 'FRACKING-MAHOMET AQUIFER', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB3329', 'FRACKING-RISK MGMT', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB3330',
#   'FRACKING-CHEMICAL DISCLOSURE',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB3380',
#   'FARMERS MKT LOCAL REG LIMITS',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB3386', 'FRACKING-BAN TASK FORCE', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB3395', 'INS CD-SPECIALTY TIER RX', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB3409',
#   'DENTIST ADMINISTER VACCINES',
#   'S',
#   'Public Act . . . . . . . . . 98-0665',
#   '6/23/2014'),
#  ('SB3411',
#   'CNTY/MUNI-NO TICKET QUOTAS',
#   'S',
#   'Public Act . . . . . . . . . 98-0650',
#   '6/16/2014'),
#  ('SB3421',
#   'ABUSED CHILD-REPORTER-TRAINING',
#   'S',
#   'Public Act . . . . . . . . . 98-0850',
#   '8/1/2014'),
#  ('SB3450',
#   'NURS HM-MANAGED CARE RIGHTS',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB3483', 'FRACKING-PROPERTY RIGHTS', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB3484',
#   'FRACKING-FLOODPLAIN TASK FORCE',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB3485', 'FRACKING-DEFINITIONS', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB3492', 'FRACKING-EARTHQUAKES', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB3546', 'CARPET STEWARDSHIP ACT', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB3557',
#   'ASSUMED BUSINESS NAME RENEWAL',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SB3558',
#   'HUMAN TRAFFICKING',
#   'S',
#   'Public Act . . . . . . . . . 98-1013',
#   '8/21/2014'),
#  ('SB3562', 'FRACKING-RADIOACTIVITY', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB3565', 'PESTICIDE EXEMPTION', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SB3575',
#   'SEX ORIENTATION CHANGE EFFORT',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SR157', 'PAY EQUITY DAY', 'S', 'Resolution Adopted', '5/14/2013'),
#  ('SR160', 'RECOGNIZE BORINQUENEERS', 'S', 'Resolution Adopted', '5/21/2013'),
#  ('SR218',
#   'AUTISM AWARENESS DAY',
#   'S',
#   'Resolution Adopted as Amended',
#   '4/25/2013'),
#  ('SR243',
#   'FINANCIAL LITERACY TASK FORCE',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SR257',
#   'URGE CONGRESS - 2013 FARM BILL',
#   'S',
#   'Resolution Adopted',
#   '5/30/2013'),
#  ('SR298',
#   "PULLMAN NAT'L PARK/MONUMENT",
#   'S',
#   'Resolution Adopted',
#   '5/31/2013'),
#  ('SR301', 'EARLY LITERACY', 'S', 'Resolution Adopted', '5/30/2013'),
#  ('SR328',
#   'CONGRESS - IMMIGRATION REFORM',
#   'S',
#   'Resolution Adopted',
#   '5/23/2013'),
#  ('SR338',
#   'SENATE ADVISORY COM-HEALTHCARE',
#   'S',
#   'Resolution Adopted; 054-000-001',
#   '5/30/2013'),
#  ('SR355', 'HFS - SMART ACT', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SR634', 'URGE CONGRESS - H.R. 875', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SR855', 'PAY EQUITY DAY', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SR1115', 'CHILD FOOD SERVICES', 'S', 'Resolution Adopted', '5/30/2014'),
#  ('SR1230',
#   'MEMORIAL-ELIZABETH GLOWCZWSKI',
#   'S',
#   'Resolution Adopted',
#   '5/23/2014'),
#  ('SJR25',
#   'SCH CD MANDATE WAIVER REPORT',
#   'S',
#   'Adopted Both Houses',
#   '4/17/2013'),
#  ('SJR27',
#   'URGE CONG-CONTRIBUTION AMENDMT',
#   'S',
#   'Adopted Both Houses',
#   '5/31/2013'),
#  ('SJR32',
#   'COMMITTEE ON EDUCATION FUNDING',
#   'S',
#   'Adopted Both Houses',
#   '5/31/2013'),
#  ('SJR42',
#   'U.S. CONSTITUTIONAL CONVENTION',
#   'S',
#   'Adopted Both Houses',
#   '12/3/2014'),
#  ('SJR58',
#   'PHARMACIES - TOBACCO PRODUCTS',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('SJR60', 'ILPMP MONTH', 'S', 'Session Sine Die', '1/13/2015'),
#  ('SJRCA40',
#   'CONAMEND-INCOME TAX RATES',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'),
#  ('HB1',
#   'MEDICAL CANNABIS',
#   'H',
#   'Public Act . . . . . . . . . 98-0122',
#   '8/1/2013'),
#  ('HB8',
#   'HUM RTS-PREGNANCY ACCOMMODATE',
#   'H',
#   'Public Act . . . . . . . . . 98-1050',
#   '8/26/2014'),
#  ('HB61',
#   'COMMUNICABLE DISEASE-DISCLOSE',
#   'H',
#   'Public Act . . . . . . . . . 98-0353',
#   '8/16/2013'),
#  ('HB62',
#   'NO REPRESENTATN W/O POPULATION',
#   'H',
#   'Session Sine Die',
#   '12/3/2014'),
#  ('HB100',
#   'MHDD ADMIN-CHESTER-TRANSPORT',
#   'H',
#   'Public Act . . . . . . . . . 98-0356',
#   '8/16/2013'),
#  ('HB190',
#   '$DFPR-TECH',
#   'H',
#   'Public Act . . . . . . . . . 98-0001',
#   '2/7/2013'),
#  ('HB946',
#   'SCH CD-HEROIN USE TASK FORCE',
#   'H',
#   'Public Act . . . . . . . . . 98-0374',
#   '8/16/2013'),
#  ('HB1010',
#   'VEHICLE CODE SUPERVISION',
#   'H',
#   'Public Act . . . . . . . . . 98-0169',
#   '8/5/2013'),
#  ('HB1052',
#   'NURSE-COLLABORATION-PRESCRIBE',
#   'H',
#   'Public Act . . . . . . . . . 98-0192',
#   '8/6/2013'),
#  ('HB1191',
#   'AGING-DEPT CONFERENCES-FEES',
#   'H',
#   'Public Act . . . . . . . . . 98-0380',
#   '8/16/2013'),
#  ('HB1233',
#   'HOSPICE PROGRM-LIMIT IN COUNTY',
#   'H',
#   'Public Act . . . . . . . . . 98-0207',
#   '8/9/2013'),
#  ('HB1288',
#   'SCHOOL CD-SPECIAL ED-COMPLAINT',
#   'H',
#   'Public Act . . . . . . . . . 98-0383',
#   '8/16/2013'),
#  ('HB1327',
#   'PHYSICIAN PROFILES-DISCLOSURE',
#   'H',
#   'Public Act . . . . . . . . . 98-0210',
#   '8/9/2013'),
#  ('HB1446',
#   'SCHOOL CD-SPECIAL ED SERVICES',
#   'H',
#   'Public Act . . . . . . . . . 98-0219',
#   '8/9/2013'),
#  ('HB1457',
#   'NURSING HOME CARE-GUARDIAN',
#   'H',
#   'Session Sine Die',
#   '12/3/2014'),
#  ('HB1462',
#   'ACCESSIBILITY STANDARDS',
#   'H',
#   'Public Act . . . . . . . . . 98-0224',
#   '8/9/2013'),
#  ('HB1463',
#   'LIQUOR-ORDERING CLOSURE',
#   'H',
#   'Public Act . . . . . . . . . 98-1054',
#   '8/26/2014'),
#  ('HB1516',
#   'MEDICAID-COMM SPOUSE-RESOURCES',
#   'H',
#   'Session Sine Die',
#   '12/3/2014'),
#  ('HB1538',
#   'MENTAL HEALTH FIRST AID TRAIN',
#   'H',
#   'Public Act . . . . . . . . . 98-0195',
#   '8/7/2013'),
#  ('HB1548',
#   'EXPUNGEMENT-CLASS 3&4 FELONIES',
#   'H',
#   'Public Act . . . . . . . . . 98-0399',
#   '8/16/2013'),
#  ('HB1854',
#   'GOVERNMENT-TECH',
#   'H',
#   'Public Act . . . . . . . . . 98-0234',
#   '8/9/2013'),
#  ('HB2213',
#   'SCH CD-DOMESTIC/SEX VIOLENCE',
#   'S',
#   'Pursuant to Senate Rule 3-9(b) / Referred to Assignments',
#   '1/4/2015'),
#  ('HB2245',
#   'ABUSED CHILD REPORTING-SCHOOL',
#   'H',
#   'Public Act . . . . . . . . . 98-0408',
#   '8/16/2013'),
#  ('HB2262',
#   'DHS-TANF-ASSET DISREGARDS',
#   'H',
#   'Public Act . . . . . . . . . 98-0114',
#   '7/29/2013'),
#  ('HB2361',
#   'VEH CD-3-AXLE MIXERS:WEIGHT',
#   'H',
#   'Public Act . . . . . . . . . 98-0410',
#   '8/16/2013'),
#  ('HB2378',
#   'CRIM ID-EXPUNGEMENT',
#   'H',
#   'Public Act . . . . . . . . . 98-1009',
#   '8/19/2014'),
#  ('HB2401',
#   'PROBATION-REDEPLOY IL',
#   'H',
#   'Public Act . . . . . . . . . 98-0060',
#   '7/8/2013'),
#  ('HB2420',
#   'SCH CD-LICENSE-FAMILY THERAPST',
#   'H',
#   'Public Act . . . . . . . . . 98-0413',
#   '8/16/2013'),
#  ('HB2470',
#   'CRIM ID-EXPUNGEMENT&SEALING',
#   'H',
#   'Public Act . . . . . . . . . 98-0163',
#   '8/5/2013'),
#  ('HB2498',
#   'COMPT-VOUCHERS FOR REFUNDS',
#   'H',
#   'Public Act . . . . . . . . . 98-0421',
#   '8/16/2013'),
#  ('HB2506',
#   'HORSE RACING-AED-TRAINING',
#   'H',
#   'Public Act . . . . . . . . . 98-0423',
#   '8/16/2013'),
#  ('HB2513',
#   'SCH CD-REQUIRE STORM SHELTER',
#   'H',
#   'Public Act . . . . . . . . . 98-0883',
#   '8/15/2014'),
#  ('HB2640',
#   'VICTIM COMP-TATTOO REMOVAL',
#   'H',
#   'Public Act . . . . . . . . . 98-0435',
#   '8/16/2013'),
#  ('HB2649',
#   'EMPLOY-CLASSIFICATION-PENALTY',
#   'H',
#   'Public Act . . . . . . . . . 98-0106',
#   '7/23/2013'),
#  ('HB2661',
#   'CONGENITAL HEART DEFECT SCREEN',
#   'H',
#   'Public Act . . . . . . . . . 98-0440',
#   '8/16/2013'),
#  ('HB2675',
#   'SCH CD-HEALTH ED-SEX ED',
#   'H',
#   'Public Act . . . . . . . . . 98-0441',
#   '8/16/2013'),
#  ('HB2760',
#   'HOME HEALTH-SERVICES-OVERSIGHT',
#   'H',
#   'Public Act . . . . . . . . . 98-0448',
#   '8/16/2013'),
#  ('HB2765',
#   'AGING-MEDICAID-SPOUSE ALLOWNCE',
#   'H',
#   'Public Act . . . . . . . . . 98-0255',
#   '8/9/2013'),
#  ('HB2802',
#   'MEDICAID-ELIGIBILTY SCORES',
#   'H',
#   'Public Act . . . . . . . . . 98-0303',
#   '8/9/2013'),
#  ('HB2897', 'CRIM CD-BODY ARMOR', 'H', 'Session Sine Die', '12/3/2014'),
#  ('HB3061',
#   'CRIM ID SEALING',
#   'H',
#   'Public Act . . . . . . . . . 98-0142',
#   '8/2/2013'),
#  ('HB3063',
#   'SCH CD-TEACHER EVALUATION PLAN',
#   'H',
#   'Public Act . . . . . . . . . 98-0470',
#   '8/16/2013'),
#  ('HB3070',
#   'SCH CD-IDENTIFY MENTAL ILLNESS',
#   'H',
#   'Public Act . . . . . . . . . 98-0471',
#   '8/16/2013'),
#  ('HB3147',
#   'JUV CT-REINSTATE PARENT RIGHT',
#   'H',
#   'Public Act . . . . . . . . . 98-0477',
#   '8/16/2013'),
#  ('HB3175',
#   'IDPH-BREAST CANCER EDUCATION',
#   'H',
#   'Public Act . . . . . . . . . 98-0479',
#   '8/16/2013'),
#  ('HB3191',
#   'NURS HOME-HOSPTL-FLU-VACCINATE',
#   'H',
#   'Public Act . . . . . . . . . 98-0271',
#   '8/9/2013'),
#  ('HB3227', 'INS CD-FIN REG FUND', 'H', 'Session Sine Die', '12/3/2014'),
#  ('HB3662',
#   'SCH CD-TRANSPORT-SAFE PASSAGE',
#   'H',
#   'Public Act . . . . . . . . . 98-1057',
#   '8/26/2014'),
#  ('HB3724',
#   'HEALTH ED-CPR/AED TRAINING REQ',
#   'H',
#   'Public Act . . . . . . . . . 98-0632',
#   '6/5/2014'),
#  ('HB3754',
#   'SCH CD-ST CHARTER SCH COMM',
#   'H',
#   'Session Sine Die',
#   '12/3/2014'),
#  ('HB3861', 'FINANCE-TECH', 'H', 'Session Sine Die', '12/3/2014'),
#  ('HB3948',
#   'EDUCATION-TECH',
#   'H',
#   'Public Act . . . . . . . . . 98-1036',
#   '8/25/2014'),
#  ('HB4207',
#   'SCH CD-BULLYING PREVENTION',
#   'H',
#   'Public Act . . . . . . . . . 98-0801',
#   '8/1/2014'),
#  ('HB4262',
#   'SCH CD-EMPLOYEE-FITNESS-GROWTH',
#   'H',
#   'Public Act . . . . . . . . . 98-0716',
#   '7/16/2014'),
#  ('HB4418',
#   'MUNI-FIRE DEPT-DISSOLUTION',
#   'H',
#   'Public Act . . . . . . . . . 98-0666',
#   '6/25/2014'),
#  ('HB4440',
#   'SCH CD-EARLY CHILDHOOD GRANT',
#   'H',
#   'Public Act . . . . . . . . . 98-0645',
#   '6/11/2014'),
#  ('HB4486',
#   'MHDD ADM CODE-MEDICATIONS',
#   'H',
#   'Public Act . . . . . . . . . 98-0901',
#   '8/15/2014'),
#  ('HB4495',
#   'MINOR-DCFS CUSTODY-AGE',
#   'H',
#   'Public Act . . . . . . . . . 98-0803',
#   '8/1/2014'),
#  ('HB4501',
#   'CONSENT BY MINOR-UNACCOMPANIED',
#   'H',
#   'Public Act . . . . . . . . . 98-0671',
#   '6/27/2014'),
#  ('HB4527',
#   'SCH CD-CHARTER SCH-ENG LEARNER',
#   'H',
#   'Public Act . . . . . . . . . 98-0639',
#   '6/9/2014'),
#  ('HB4535',
#   'REGULATION-TECH',
#   'H',
#   'Public Act . . . . . . . . . 98-0993',
#   '8/18/2014'),
#  ('HB4542',
#   'SCH CD-HEROIN USE TASK FORCE',
#   'H',
#   'Public Act . . . . . . . . . 98-0861',
#   '8/5/2014'),
#  ('HB4733',
#   'UNEMPLOYMENT-NEWSPAPER DELIVER',
#   'H',
#   'Placed on Calendar Order of Concurrence Senate Amendment(s) 3, 4',
#   '12/4/2014'),
#  ('HB5286',
#   'SCH CD-PRINCIPAL ENDORSEMENT',
#   'H',
#   'Public Act . . . . . . . . . 98-0917',
#   '8/15/2014'),
#  ('HB5393',
#   'SCH CD-TEACHING EXCELLENCE PRO',
#   'H',
#   'Public Act . . . . . . . . . 98-0646',
#   '6/11/2014'),
#  ('HB5397',
#   'SCH CD-PHYSICAL FITNESS REPORT',
#   'H',
#   'Public Act . . . . . . . . . 98-0859',
#   '8/4/2014'),
#  ('HB5412',
#   'DPH-COMMUNITY HEALTH WORKERS',
#   'H',
#   'Public Act . . . . . . . . . 98-0796',
#   '7/31/2014'),
#  ('HB5485',
#   'PUBLIC LABOR REL-MANNING',
#   'H',
#   'Public Act . . . . . . . . . 98-1151',
#   '1/7/2015'),
#  ('HB5622',
#   'WAGE PAYMENT PAYROLL CARD',
#   'H',
#   'Public Act . . . . . . . . . 98-0862',
#   '8/6/2014'),
#  ('HB5657',
#   'FARMERS MKT LOCAL REG LIMITS',
#   'H',
#   'Public Act . . . . . . . . . 98-0660',
#   '6/23/2014'),
#  ('HB5701',
#   'EMPLOYEE BACKGROUND CHECK',
#   'H',
#   'Public Act . . . . . . . . . 98-0774',
#   '7/21/2014'),
#  ('HB5707',
#   'SCH CD-BULLYING POLICY',
#   'H',
#   'Public Act . . . . . . . . . 98-0669',
#   '6/26/2014'),
#  ('HB5872',
#   'VEH CD-BLUE STAR BANNER PLATE',
#   'H',
#   'Session Sine Die',
#   '12/3/2014'),
#  ('HB5975',
#   'MEDICAID-ID/DD-BILLING CLAIMS',
#   'H',
#   'Session Sine Die',
#   '12/3/2014'),
#  ('HB5990',
#   'COUNTIES-CHILD ADVOCACY CTR',
#   'H',
#   'Public Act . . . . . . . . . 98-0809',
#   '8/1/2014'),
#  ('HJR31',
#   'SCH CD MANDATE WAIVER REPORT',
#   'H',
#   'Adopted Both Houses',
#   '10/23/2013'),
#  ('HJR77',
#   'LATINOS WITH DISABILITIES TF',
#   'H',
#   'Adopted Both Houses',
#   '5/30/2014'),
#  ('HJR83',
#   'SCH CD MANDATE WAIVER REPORT',
#   'H',
#   'Session Sine Die',
#   '12/3/2014'),
#  ('HJR97',
#   'PRESCRIPTION MONITORING MONTH',
#   'H',
#   'Adopted Both Houses',
#   '5/30/2014'),
#  ('HJR107',
#   'SCH CD MANDATE WAIVER REPORT',
#   'H',
#   'Adopted Both Houses',
#   '12/4/2014')]

# %%
from random import randint
for i in range(10):
    print("hello")
    time.sleep(randint(1,3))
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
